# %%
from tqdm import tqdm

# %%
for i in tqdm(range(int(9e6))):
    pass
# Out:
# 100%|████████████████████████████████████████████████| 9000000/9000000 [00:01<00:00, 4740112.70it/s]

# %%
for i in tqdm(range(int(9e6)), desc='Extracting URLs from search page'):
    pass
# Out:
# Extracting post information: 100%|███████████████████| 9000000/9000000 [00:01<00:00, 4982456.68it/s]

# %%
test_dict = {'hey':(1, 3), 'ya':(1,2,3)}

# %%
for key in tqdm(test_dict.keys()):
    pass
# Out:
# 100%|███████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 7781.64it/s]

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm  # notebook compatible
import time
for i1 in tqdm(range(5)):
    for i2 in tqdm(range(300), leave=False):
        # do something, e.g. sleep
        time.sleep(0.01)
# Out:
# ...
#  20%|█████████████                                                    | 1/5 [00:03<00:14,  3.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/lp/jgdr2r255gz098q__v2pjv0r0000gn/T/ipykernel_75146/1162190477.py in <module>
#       5     for i2 in tqdm(range(300), leave=False):
#       6         # do something, e.g. sleep
# ----> 7         time.sleep(0.01)
#
# KeyboardInterrupt:

# %%
# %store -r

# %%
stored_search_pages
# Out:
# {('Alabama', 'auburn'): [<Response [200]>],
#  ('Alabama', 'bham'): [<Response [200]>],
#  ('Alabama', 'dothan'): [<Response [200]>],
#  ('Alabama', 'shoals'): [<Response [200]>],
#  ('Alabama', 'gadsden'): [<Response [200]>],
#  ('Alabama', 'huntsville'): [<Response [200]>],
#  ('Alabama', 'mobile'): [<Response [200]>],
#  ('Alabama', 'montgomery'): [<Response [200]>],
#  ('Alabama', 'tuscaloosa'): [<Response [200]>],
#  ('Alaska', 'anchorage'): [<Response [200]>],
#  ('Alaska', 'fairbanks'): [<Response [200]>],
#  ('Alaska', 'kenai'): [<Response [200]>],
#  ('Alaska', 'juneau'): [<Response [200]>],
#  ('Arizona', 'flagstaff'): [<Response [200]>],
#  ('Arizona', 'mohave'): [<Response [200]>],
#  ('Arizona', 'phoenix'): [<Response [200]>],
#  ('Arizona', 'prescott'): [<Response [200]>],
#  ('Arizona', 'showlow'): [<Response [200]>],
#  ('Arizona', 'sierravista'): [<Response [200]>],
#  ('Arizona', 'tucson'): [<Response [200]>],
#  ('Arizona', 'yuma'): [<Response [200]>],
# ...

# %%
stored_search_pages[('California', 'sfbay')]
# Out:
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %%
search_page_url_dict[('California', 'sfbay')]
# Out:
# [<li class="result-row" data-pid="7442296340" data-repost-of="6366934907">
#  <a class="result-image gallery empty" href="https://sfbay.craigslist.org/pen/lss/d/south-san-francisco-math-and-chemistry/7442296340.html"></a>
#  <div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2022-02-05 15:51" title="Sat 05 Feb 03:51:11 PM">Feb  5</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7442296340" href="https://sfbay.craigslist.org/pen/lss/d/south-san-francisco-math-and-chemistry/7442296340.html" id="postid_7442296340">Math and Chemistry Tutor</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-hood"> ( peninsula )</span>
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
# ...
